# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import pandas_gbq
#pip install pygraphviz
#import pygraphviz

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 20]

# %%
Deals = 'TBiz BB Capped Advanced'

# %%
'''
---nice insight
TBiz BB Capped Advanced

Fixed Line Look-Alike Bundle - Residential - nice

80	no edges
Huawei E5573 + Free SIM & Connection on SmartInternet - 5GB  +  @ R149 x 24 Months (Includes 10GB Anytime Telkom Data for 6 Months)
M
17055
7209
7523
15551
81	 nice - days - 
Unlimited Business DSL (10Mbps) M2M
F
16992
3456
6619
10965
82	 too cluttered
OptiCon eMG Rental
F
16805
6470
5900
13976
83	 only one action to stage 2
Huawei P30 lite Midnight Black + Free SIM & Connection on FreeMe 1GB + 10GB Telkom Data X 3 Months @ R299 x 24 Months
M
16506
6616
7644
14743
84	nice - days -
Hunting Facilities Offer
F
16496
10972
11898
13467
85	nice - days -
Unlimited Business DSL (4 Mbps) 24 Months
F
16477
3897
8452
7305
86	nice - days -
FMC TI Mobile Consumer
F
16463
4436
5420
13623
87	no edges
Hisense U962 Gunmetal Grey + Free SIM & Connection on FreeMe 500MB @ R99 x 24 Months
M
16214
6111
6519
15064
88	no edges
 Sim-Only + Free SIM & Connection on Telkom Data On the Go 10GB @ R99 x 24 Months
M
16205
10302
11326
14339
89	nice - days -
TBiz Starter NP
F
15828
2700
5044
12753
90	no edges
Huawei E5573 + Free SIM & Connection on Telkom Data On the Go 10GB Top-Up +  @ R169 x 24 Months
M
15806
9114
9435
14711
91	no edges
None + Free R200 SIM & Connection Fee on Smart One Rate TopUp @R0pm x 24 Months, + Free CLIP and E-Mail Itemised Billing
M
15792
1
13895
13886
92	no edges
Huawei P Smart Black + Free SIM & Connection on FreeMe 1GB + 100 FreeMe Promo-Net Minutes & 10GB Telkom Data X 6 Months @ R169 x 24 Months
M
15596
6234
7611
14569
93	no edges
Smart One-Rate TopUp Deal
NGN
15259
11
14185
14187
94	
Huawei P30 lite Peacock Blue + Free SIM & Connection on FreeMe 1GB + 10GB Telkom Data X 3 Months @ R299 x 24 Months
M
15083
6100
7064
13461
95	
Huawei B618 + Free SIM & Connection on SmartBroadband Wireless-50GB + 50GB Night-Surfer @ R459 x 24 Months + Free 20GB Telkom Bundle
M
14942
8317
8465
14001
96	
Huawei E5330 + Free SIM & Connection on SmartInternet - 1GB @ R89 x 24 Months
M
14731
6056
6360
13574
97	
Unlimited Home DSL 10Mbps (Month to Month)
F
14646
3118
5697
9662
98	
Huawei P20  Lite Blue + Free SIM & Connection on FreeMe 1GB + 10GB Telkom Data X 3 months @ R269 x 24 Months
M
14517
4860
5392
13793
99	
Sim Only + Free SIM & Connection on SmartSaver 50 @ R49 x 24 Months + Free CLIP & Email Itemised Billing
M
14468
4597
4664
13218
100	no edges
M2M Basic
NGN
14229
35
11343
12461


180	
Huawei E5573 + Free SIM & Connection on Telkom Data On the Go 10GB @ R139 x 24 Months
M
7885
4552
4838
6236
181	 too many stages 8
FLLA Junction - Business
F
7849
1512
3255
4740
182	 nice - interesting pattern
TBiz BB Capped Advanced
F
7846
1356
2664
6178
183	 ok
VPN Supreme Via Metro Ethernet
F
7673
169
4839
3250
184	 too many stages 9
Unlimited Business DSL (8Mbps) 24 Months
F
7606
1457
2931
4658
185	 ok - good it neighborless removed
Pre-Paid Top-Up
F
7600
3822
3860
6401
186	 no edges
Huawei P20  Lite Black + Free SIM & Connection on FreeMe 1GB TopUp @ R269 x 24 Months
M
7553
2851
3237
7068
187	
Free SIM & Connection on Smart OneRate @ R10 x 24 Months
M
7301
36
6102
6579
188	 no edges
SmartInternet Top-Up 1GB Deal
NGN
7278
3915
4220
6259
189	 ok
Unlimited Home Fibre 20Mbps (24 Month)
F
7277
1071
2815
3986
190	
SmartPlan 100 Deal
NGN
7254
1920
3198
6194
191	
Huawei P10 Lite Gold + Free SIM & Connection on FreeMe 1GB + 100 All-Net Minutes X 24 and 10GB Telkom Data X 3 months @ R249 x 24 Months
M
7185
2556
2657
6702
192	
Business ECDSL Bundle 12 Month Term
F
7125
2263
2731
5812
193	
Business DSL 10Mbps_Promo (24 Month)
F
7116
1300
2383
5321
194	
Business ECDSL 12 Month Term
F
7104
2427
2869
5692
195	
Telkom Data On the Go 5GB Top-up Deal
NGN
7058
3522
3614
6105
196	
Unlimited Business DSL (10 Mbps) M2M
F
7003
1943
4110
3267
197	 too many stages
Router Card and Switches
F
6977
50
5208
1802
198	
Huawei Mate 20 Lite Black + Free SIM & Connection on FreeMe 1GB + 100 FreeMe Promo-Net Minutes & 10GB Telkom Data X 6 Months @ R399 x 24 Months
M
6943
2473
2844
6458
199	
Sim-Only + Free SIM & Connection on FreeMe 20GB @ R499 x 24 Months (April 2019 DoM, Month to Month with No cancellation fee)
M
6934
2823
4300
5947
200	
Huawei E5573 + Free SIM & Connection on Telkom Data On the Go 10GB +  @ R169 x 24 Months
M
6929
4099
4301
6499


*SmartBroadband Wireless 20GB Deal
SmartBroadband Wireless Uncapped All Hours Deal
*Unlimited Home DSL 10Mbps (Month to Month)
NGN OpenServe DSL
Hunting Facilities Offer
BizTalk Term Contract
ADSL Term Contract
Wholesale ECDSL
Sim Only + Free SIM & Connection on SmartSaver 50 @ R49 x 24 Months + Free CLIP & Email Itemised Billing
Huawei E5330 + Free SIM & Connection on SmartInternet - 1GB @ R89 x 24 Months
Huawei P20  Lite Blue + Free SIM & Connection on FreeMe 1GB + 10GB Telkom Data X 3 months @ R269 x 24 Months
'''
# Out:
# '\n---nice insight\nTBiz BB Capped Advanced\n\nFixed Line Look-Alike Bundle - Residential - nice\n\n80\tno edges\nHuawei E5573 + Free SIM & Connection on SmartInternet - 5GB  +  @ R149 x 24 Months (Includes 10GB Anytime Telkom Data for 6 Months)\nM\n17055\n7209\n7523\n15551\n81\t nice - days - \nUnlimited Business DSL (10Mbps) M2M\nF\n16992\n3456\n6619\n10965\n82\t too cluttered\nOptiCon eMG Rental\nF\n16805\n6470\n5900\n13976\n83\t only one action to stage 2\nHuawei P30 lite Midnight Black + Free SIM & Connection on FreeMe 1GB + 10GB Telkom Data X 3 Months @ R299 x 24 Months\nM\n16506\n6616\n7644\n14743\n84\tnice - days -\nHunting Facilities Offer\nF\n16496\n10972\n11898\n13467\n85\tnice - days -\nUnlimited Business DSL (4 Mbps) 24 Months\nF\n16477\n3897\n8452\n7305\n86\tnice - days -\nFMC TI Mobile Consumer\nF\n16463\n4436\n5420\n13623\n87\tno edges\nHisense U962 Gunmetal Grey + Free SIM & Connection on FreeMe 500MB @ R99 x 24 Months\nM\n16214\n6111\n6519\n15064\n88\tno edges\n Sim-Only + Free SIM & Connection on Telkom Data On the Go 10GB @ R99 x 24 Months\nM\n16205\n10302\n11326\n14339\n89\tnice - days -\nTBiz Starter NP\nF\n15828\n2700\n5044\n12753\n90\tno edges\nHuawei E5573 + Free SIM & Connection on Telkom Data On the Go 10GB Top-Up +  @ R169 x 24 Months\nM\n15806\n9114\n9435\n14711\n91\tno edges\nNone + Free R200 SIM & Connection Fee on Smart One Rate TopUp @R0pm x 24 Months, + Free CLIP and E-Mail Itemised Billing\nM\n15792\n1\n13895\n13886\n92\tno edges\nHuawei P Smart Black + Free SIM & Connection on FreeMe 1GB + 100 FreeMe Promo-Net Minutes & 10GB Telkom Data X 6 Months @ R169 x 24 Months\nM\n15596\n6234\n7611\n14569\n93\tno edges\nSmart One-Rate TopUp Deal\nNGN\n15259\n11\n14185\n14187\n94\t\nHuawei P30 lite Peacock Blue + Free SIM & Connection on FreeMe 1GB + 10GB Telkom Data X 3 Months @ R299 x 24 Months\nM\n15083\n6100\n7064\n13461\n95\t\nHuawei B618 + Free SIM & Connection on SmartBroadband Wireless-50GB + 50GB Night-Surfer @ R459 x 24 Months + Free 20GB Telkom Bundle\nM\n14942\n8317\n8465\n14001\n96\t\nHuawei E5330 + Free SIM & Connection on SmartInternet - 1GB @ R89 x 24 Months\nM\n14731\n6056\n6360\n13574\n97\t\nUnlimited Home DSL 10Mbps (Month to Month)\nF\n14646\n3118\n5697\n9662\n98\t\nHuawei P20  Lite Blue + Free SIM & Connection on FreeMe 1GB + 10GB Telkom Data X 3 months @ R269 x 24 Months\nM\n14517\n4860\n5392\n13793\n99\t\nSim Only + Free SIM & Connection on SmartSaver 50 @ R49 x 24 Months + Free CLIP & Email Itemised Billing\nM\n14468\n4597\n4664\n13218\n100\tno edges\nM2M Basic\nNGN\n14229\n35\n11343\n12461\n\n\n180\t\nHuawei E5573 + Free SIM & Connection on Telkom Data On the Go 10GB @ R139 x 24 Months\nM\n7885\n4552\n4838\n6236\n181\t too many stages 8\nFLLA Junction - Business\nF\n7849\n1512\n3255\n4740\n182\t nice - interesting pattern\nTBiz BB Capped Advanced\nF\n7846\n1356\n2664\n6178\n183\t ok\nVPN Supreme Via Metro Ethernet\nF\n7673\n169\n4839\n3250\n184\t too many stages 9\nUnlimited Business DSL (8Mbps) 24 Months\nF\n7606\n1457\n2931\n4658\n185\t ok - good it neighborless removed\nPre-Paid Top-Up\nF\n7600\n3822\n3860\n6401\n186\t no edges\nHuawei P20  Lite Black + Free SIM & Connection on FreeMe 1GB TopUp @ R269 x 24 Months\nM\n7553\n2851\n3237\n7068\n187\t\nFree SIM & Connection on Smart OneRate @ R10 x 24 Months\nM\n7301\n36\n6102\n6579\n188\t no edges\nSmartInternet Top-Up 1GB Deal\nNGN\n7278\n3915\n4220\n6259\n189\t ok\nUnlimited Home Fibre 20Mbps (24 Month)\nF\n7277\n1071\n2815\n3986\n190\t\nSmartPlan 100 Deal\nNGN\n7254\n1920\n3198\n6194\n191\t\nHuawei P10 Lite Gold + Free SIM & Connection on FreeMe 1GB + 100 All-Net Minutes X 24 and 10GB Telkom Data X 3 months @ R249 x 24 Months\nM\n7185\n2556\n2657\n6702\n192\t\nBusiness ECDSL Bundle 12 Month Term\nF\n7125\n2263\n2731\n5812\n193\t\nBusiness DSL 10Mbps_Promo (24 Month)\nF\n7116\n1300\n2383\n5321\n194\t\nBusiness ECDSL 12 Month Term\nF\n7104\n2427\n2869\n5692\n195\t\nTelkom Data On the Go 5GB Top-up Deal\nNGN\n7058\n3522\n3614\n61 ...

# %%
query = """
SELECT *
FROM `bcx-insights.telkom_customerexperience.orders_20190926_00_anon`
WHERE DEAL_DESC = '{}'
ORDER BY ORDER_CREATION_DATE, ACTION_CREATION_DATE, ORDER_ID_ANON
""".format(Deals)

# %%
query
# Out:
# "\nSELECT *\nFROM `bcx-insights.telkom_customerexperience.orders_20190926_00_anon`\nWHERE DEAL_DESC = 'TBiz BB Capped Advanced'\nORDER BY ORDER_CREATION_DATE, ACTION_CREATION_DATE, ORDER_ID_ANON\n"

# %%
orders_df = pd.read_gbq(query,
                project_id = 'bcx-insights',
                dialect = 'standard')

# %%
orders_df.tail(3)
# Out:
#      ORDER_STATUS_DESC       ORDER_CREATION_DATE ACTION_STATUS_DESC  \
# 7843              Done 2019-09-18 06:41:04+00:00               Done
# 7844              Done 2019-09-18 06:41:06+00:00               Done
# 7845              Done 2019-09-18 06:41:14+00:00               Done
#
#      ACTION_TYPE ACTION_TYPE_DESC      ACTION_CREATION_DATE  \
# 7843          HS     Hard Suspend 2019-09-18 06:41:04+00:00
# 7844          HS     Hard Suspend 2019-09-18 06:41:05+00:00
# 7845          HS     Hard Suspend 2019-09-18 06:41:13+00:00
#
#      ORIGINAL_SALES_CHANNEL_DESC CURRENT_SALES_CHANNEL_DESC  \
# 7843                 Call Center                Call Center
# 7844                 Call Center                Call Center
# 7845                 Call Center                Call Center
#
#                     DEAL_DESC                 PROV_DATE  \
# 7843  TBiz BB Capped Advanced 2019-09-18 23:59:59+00:00
# 7844  TBiz BB Capped Advanced 2019-09-18 23:59:59+00:00
# 7845  TBiz BB Capped Advanced 2019-09-18 23:59:59+00:00
#
#                     CLOSE_DATE OPEN_CLOSE_INDIC SOURCE        ORDER_ID_ANON  \
# 7843 2019-09-18 06:41:33+00:00                C      F -3623129877457504494
# 7844 2019-09-18 06:41:26+00:00                C      F -4085417724732539719
# 7845 2019-09-18 06:41:23+00:00                C      F -8459172821802969048
#
#           ACCOUNT_NO_ANON          MSISDN_ANON  ORDER_ACTION_ID_ANON
# 7843  9179685449604117757 -3746220542732778290  -3107359610750660354
# 7844  9179685449604117757   486548533846911321   5149598645928986403
# 7845  9179685449604117757 -3379634856020541348   7366941129127761236

# %%
len(orders_df)
# Out:
# 7846

# %%
orders_df = orders_df.drop_duplicates()

# %%
len(orders_df)
# Out:
# 6816

# %%
orders_df['MSISDN_ANON'] = orders_df['MSISDN_ANON'].astype(str)

# %%
orders_df['ORDER_ID_ANON'] = orders_df['ORDER_ID_ANON'].astype(str)

# %%
unique_col = 'combo'

# %%
orders_df[unique_col] = orders_df['MSISDN_ANON']+'_'+orders_df['ORDER_ID_ANON']

# %%
orders_df['stage'] = orders_df.groupby(unique_col).cumcount()+1

# %%
final_stage = orders_df[[unique_col,'stage']].groupby(unique_col).max()

# %%
final_stage.rename(columns={'stage':'final_stage'}, inplace=True)

# %%
final_stage.head()
# Out:
#                                            final_stage
# combo
# -1002689210467033689_-4097911263059863394            2
# -1002689210467033689_-4708518482210045078            1
# -1002689210467033689_-6805338612372424491            1
# -1002689210467033689_4694949585886651643             1
# -1002689210467033689_6330235094427327840             1

# %%
orders_df = pd.merge(orders_df, final_stage, on=unique_col, how='outer')

# %%
orders_df.head()
# Out:
#   ORDER_STATUS_DESC       ORDER_CREATION_DATE ACTION_STATUS_DESC ACTION_TYPE  \
# 0              Done 2018-09-19 00:01:40+00:00               Done          CR
# 1              Done 2018-09-19 00:08:19+00:00               Done          CR
# 2              Done 2018-09-19 00:08:22+00:00               Done          CR
# 3              Done 2018-09-19 00:11:18+00:00               Done          CR
# 4              Done 2018-09-19 00:11:26+00:00               Done          CR
#
#                            ACTION_TYPE_DESC      ACTION_CREATION_DATE  \
# 0  Resume from Suspension due to Collection 2018-09-19 00:00:34+00:00
# 1  Resume from Suspension due to Collection 2018-09-19 00:02:30+00:00
# 2  Resume from Suspension due to Collection 2018-09-19 00:08:04+00:00
# 3  Resume from Suspension due to Collection 2018-09-19 00:11:16+00:00
# 4  Resume from Suspension due to Collection 2018-09-19 00:11:25+00:00
#
#   ORIGINAL_SALES_CHANNEL_DESC CURRENT_SALES_CHANNEL_DESC  \
# 0                 Call Center                Call Center
# 1                 Call Center                Call Center
# 2                 Call Center                Call Center
# 3                 Call Center                Call Center
# 4                 Call Center                Call Center
#
#                  DEAL_DESC                 PROV_DATE  \
# 0  TBiz BB Capped Advanced 2018-09-19 23:59:59+00:00
# 1  TBiz BB Capped Advanced 2018-09-19 23:59:59+00:00
# 2  TBiz BB Capped Advanced 2018-09-19 23:59:59+00:00
# 3  TBiz BB Capped Advanced 2018-09-19 23:59:59+00:00
# 4  TBiz BB Capped Advanced 2018-09-19 23:59:59+00:00
#
#                  CLOSE_DATE OPEN_CLOSE_INDIC SOURCE         ORDER_ID_ANON  \
# 0 2018-09-19 02:02:36+00:00                C      F   8014743664010143874
# 1 2018-09-19 02:02:46+00:00                C      F   4896610020755115874
# 2 2018-09-19 02:03:30+00:00                C      F  -7402119597778060068
# 3 2018-09-19 02:35:04+00:00                C      F   -891254573908734095
# 4 2018-09-19 02:08:45+00:00                C      F  -4980229336441433325
#
#        ACCOUNT_NO_ANON           MSISDN_ANON  ORDER_ACTION_ID_ANON  \
# 0  4880988462641041588   8267334465643049670    -22945164240823800
# 1  4880988462641041588   5883010122451860359   6206333873489587611
# 2 -7190704940419402037   6881390640784013810   1589287855847731834
# 3 -1202927280942112478  -7917274003366893655   7874500299927321830
# 4 -1202927280942112478  -3858268071889160291  -6140598406575839500
#
#                                        combo  stage  final_stage
# 0    8267334465643049670_8014743664010143874      1            1
# 1    5883010122451860359_4896610020755115874      1            1
# 2   6881390640784013810_-7402119597778060068      1            1
# 3   -7917274003366893655_-891254573908734095      1            1
# 4  -3858268071889160291_-4980229336441433325      1            1

# %%
orders_df['stage'] = orders_df['stage'].astype(str)

# %%
orders_df['ActionType_OrderStatus'] = orders_df['ACTION_TYPE_DESC'] +' * '+ orders_df['ORDER_STATUS_DESC']

# %%
type_status = list(orders_df['ActionType_OrderStatus'].unique())

# %%
orders_df['stage_ActionType_OrderStatus'] = orders_df['stage'] +') * '+ orders_df['ACTION_TYPE_DESC'] +' * '+ orders_df['ORDER_STATUS_DESC']

# %%
orders_df.tail(3)
# Out:
#      ORDER_STATUS_DESC       ORDER_CREATION_DATE ACTION_STATUS_DESC  \
# 6813              Done 2019-09-18 06:41:04+00:00               Done
# 6814              Done 2019-09-18 06:41:06+00:00               Done
# 6815              Done 2019-09-18 06:41:14+00:00               Done
#
#      ACTION_TYPE ACTION_TYPE_DESC      ACTION_CREATION_DATE  \
# 6813          HS     Hard Suspend 2019-09-18 06:41:04+00:00
# 6814          HS     Hard Suspend 2019-09-18 06:41:05+00:00
# 6815          HS     Hard Suspend 2019-09-18 06:41:13+00:00
#
#      ORIGINAL_SALES_CHANNEL_DESC CURRENT_SALES_CHANNEL_DESC  \
# 6813                 Call Center                Call Center
# 6814                 Call Center                Call Center
# 6815                 Call Center                Call Center
#
#                     DEAL_DESC                 PROV_DATE  ... SOURCE  \
# 6813  TBiz BB Capped Advanced 2019-09-18 23:59:59+00:00  ...      F
# 6814  TBiz BB Capped Advanced 2019-09-18 23:59:59+00:00  ...      F
# 6815  TBiz BB Capped Advanced 2019-09-18 23:59:59+00:00  ...      F
#
#              ORDER_ID_ANON      ACCOUNT_NO_ANON           MSISDN_ANON  \
# 6813  -3623129877457504494  9179685449604117757  -3746220542732778290
# 6814  -4085417724732539719  9179685449604117757    486548533846911321
# 6815  -8459172821802969048  9179685449604117757  -3379634856020541348
#
#       ORDER_ACTION_ID_ANON                                      combo  stage  \
# 6813  -3107359610750660354  -3746220542732778290_-3623129877457504494      1
# 6814   5149598645928986403    486548533846911321_-4085417724732539719      1
# 6815   7366941129127761236  -3379634856020541348_-8459172821802969048      1
#
#      final_stage ActionType_OrderStatus  stage_ActionType_OrderStatus
# 6813           1    Hard Suspend * Done      1) * Hard Suspend * Done
# 6814           1    Hard Suspend * Done      1) * Hard Suspend * Done
# 6815           1    Hard Suspend * Done      1) * Hard Suspend * Done
#
# [3 rows x 22 columns]

# %%
#orders_df.groupby(unique_col)

# %%
customers = list(orders_df[unique_col].unique())

# %%
sorted_df = orders_df.sort_values('stage', ascending=False)
sorted_df.head(3)
# Out:
#     ORDER_STATUS_DESC       ORDER_CREATION_DATE ACTION_STATUS_DESC  \
# 336              Done 2018-11-20 10:10:17+00:00               Done
# 410              Done 2018-10-09 14:54:01+00:00               Done
# 588              Done 2018-10-10 13:54:29+00:00               Done
#
#     ACTION_TYPE            ACTION_TYPE_DESC      ACTION_CREATION_DATE  \
# 336          MS  Move Outdoor Same Exchange 2018-08-27 00:00:00+00:00
# 410          CM          Cease Part Of Move 2018-10-02 00:00:00+00:00
# 588          PR                     Provide 2018-10-10 00:00:00+00:00
#
#     ORIGINAL_SALES_CHANNEL_DESC  CURRENT_SALES_CHANNEL_DESC  \
# 336                 Call Center                 Call Center
# 410              Consumer Sales              Consumer Sales
# 588  Deregulated PABX Suppliers  Deregulated PABX Suppliers
#
#                    DEAL_DESC                 PROV_DATE  ... SOURCE  \
# 336  TBiz BB Capped Advanced 2018-11-20 10:11:40+00:00  ...      F
# 410  TBiz BB Capped Advanced 2018-10-09 14:56:35+00:00  ...      F
# 588  TBiz BB Capped Advanced 2018-10-10 13:55:45+00:00  ...      F
#
#            ORDER_ID_ANON      ACCOUNT_NO_ANON           MSISDN_ANON  \
# 336  4892878901532782903  -799468424400376874  -5358406379613644979
# 410  4834273730448523809  5156758895250942611   3842282672409691663
# 588  -152669041816858573  -645405488242463116   5100925659296341771
#
#      ORDER_ACTION_ID_ANON                                     combo  stage  \
# 336  -8130465519461665528  -5358406379613644979_4892878901532782903      4
# 410  -6243901908868668088   3842282672409691663_4834273730448523809      4
# 588   7122014269109539755   5100925659296341771_-152669041816858573      4
#
#     final_stage             ActionType_OrderStatus  \
# 336           4  Move Outdoor Same Exchange * Done
# 410           4          Cease Part Of Move * Done
# 588           4                     Provide * Done
#
#                stage_ActionType_OrderStatus
# 336  4) * Move Outdoor Same Exchange * Done
# 410          4) * Cease Part Of Move * Done
# 588                     4) * Provide * Done
#
# [3 rows x 22 columns]

# %%
len(orders_df[orders_df['stage']=='2'])
# Out:
# 157

# %%
len(customers)
# Out:
# 6650

# %%
# Create a networkx graph object
J = nx.Graph()

# %%
J.clear()

# %%
max_stage=max(orders_df['stage'].astype(int))
max_stage
# Out:
# 4

# %%
actions = list(orders_df['stage_ActionType_OrderStatus'].unique())

# %%
J.add_node(Deals[:3],posi=(0.4,10), color = 'purple')

# %%
for i in range(1,max_stage+1):
  
  stage_actions = list(orders_df[orders_df['stage']==str(i)]['stage_ActionType_OrderStatus'].unique())
  #print(stage_actions)
  for k in range(len(stage_actions)):
    label = stage_actions[k]
    #print(label)
    label = label.split('* ',1)
    label = label[1]
    #print(label)
    height =  type_status.index(label) +1
    #print(height)
    J.add_node(stage_actions[k],posi=(i*1.25,height))
    #print(stage_actions[k])
    #print((i,k+1))

# %%
J.nodes(data = True)
# Out:
# NodeDataView({'1) * Move Outdoor Other Exchange * Cancelled': {'posi': (1.25, 19)}, '1) * Change - No Dispatch * Cancelled': {'posi': (1.25, 18)}, '1) * Move Outdoor Other Exchange * Negotiation': {'posi': (1.25, 42)}, '1) * Provide Same As * Cancelled': {'posi': (1.25, 38)}, '1) * Provide * Cancelled': {'posi': (1.25, 25)}, '1) * Provide Part Of Migrate * Amended': {'posi': (1.25, 40)}, '2) * Cease * Done': {'posi': (2.5, 10)}, '1) * Change - Dispatchable * Done': {'posi': (1.25, 26)}, '1) * Provide * Done': {'posi': (1.25, 12)}, '1) * Cease * Cancelled': {'posi': (1.25, 13)}, '1) * Change * Cancelled': {'posi': (1.25, 15)}, '1) * Re-establish * Cancelled': {'posi': (1.25, 46)}, '2) * Cease Part Of Move * Negotiation': {'posi': (2.5, 43)}, '1) * Provide Part Of Migrate * Cancelled': {'posi': (1.25, 30)}, '2) * Change * Done': {'posi': (2.5, 16)}, '1) * Move Outdoor Same Exchange * Done': {'posi': (1.25, 17)}, '1) * Cease Part Of Migrate * Completion': {'posi': (1.25, 36)}, '1) * Receive  Ownership * Done': {'posi': (1.25, 6)}, '2) * Cease Part Of Migrate * Done': {'posi': (2.5, 9)}, '1) * Cease Part Of Migrate * Cancelled': {'posi': (1.25, 8)}, '1) * Re-establish * Done': {'posi': (1.25, 32)}, '2) * Change - No Dispatch * Done': {'posi': (2.5, 7)}, '1) * Hard Suspend * Done': {'posi': (1.25, 4)}, '2) * Cease Part Of Move * Done': {'posi': (2.5, 22)}, '2) * Cease Part Of Move * Cancelled': {'posi': (2.5, 20)}, '1) * Change BAN To BAN * Done': {'posi': (1.25, 39)}, '1) * Provide Part Of Move * Done': {'posi': (1.25, 24)}, '1) * Change * Done': {'posi': (1.25, 16)}, '1) * Move Outdoor Same Exchange * Cancelled': {'posi': (1.25, 14)}, '1) * Indoor transfer * Done': {'posi': (1.25, 28)}, '2) * Change - T&M Dispatch * Done': {'posi': (2.5, 45)}, '2) * Provide * Cancelled': {'posi': (2.5, 25)}, '1) * Indoor transfer * Cancelled': {'posi': (1.25, 33)}, '2) * Move Outdoor Same Exchange * Done': {'posi': (2.5, 17)}, '1) * Cease due to Collection * Cancelled': {'posi': (1.25, 27)}, '2) * Change - Dispatchable * Done': {'posi': (2.5, 26)}, '2) * Receive  Ownership * Done': {'posi': (2.5, 6)}, '1) * Cease Part Of Move * Done': {'posi': (1.25, 22)}, '3) * Move Outdoor Other Exchange * Done': {'posi': (3.75, 21)}, '1) * Modify Address * Done': {'posi': (1.25, 29)}, '2) * Move Outdoor Same Exchange * Cancelled': {'posi': (2.5, 14)}, '1) * Change BAN To BAN * Cancelled': {'posi': (1.25, 34)}, '3) * Provide * Cancelled': {'posi': (3.75, 25)}, '2) * Provide Part Of Migrate * Done': {'posi': (2.5, 11)}, '4) * Move Outdoor Same Exchange * Done': {'posi': (5.0, 17)}, '1) * Change SN * Done': {'posi': (1.25, 35)}, '1) * Move Outdoor Other Exchange * Done': {'posi': (1.25, 21)}, '1) * Cease Part Of Migrate * Negotiation': {'posi': (1.25, 48)}, '1) * Change - T&M Dispatch * Cancelled': {'posi': (1.25, 37)}, '1) * Cease * Negotiation': {'posi': (1.25, 47)}, '2) * Re-establish * Done': {'posi': (2.5, 32)}, '1) * Move Outdoor Same Exchange * Delivery': {'posi': (1.25, 44)}, '1) * Cease due to Collection * Done': {'posi': (1.25, 2)}, 'TBi': {'posi': (0.4, 10), 'color': 'purple'}, '1) * Cease * Done': {'posi': (1.25, 10)}, '4) * Provide * Done': {'posi': (5.0, 12)}, '1) * Cease * Delivery': {'posi': (1.25, 41)}, '1) * Change - Dispatchable * Cancelled': {'posi': (1.25, 5)}, '4) * Cease Part Of Move * Done': {'posi': (5.0, 22)}, '2) * Provide Part Of Move * Done': {'posi': (2.5, 24)}, '1) * Receive  Ownership * Cancelled': {'posi': (1.25, 31)}, '1) * Resume from Suspension due to Collection * Done': {'posi': (1.25, 1)}, '1) * Change - No Dispatch * Done': {'posi': (1.25, 7)}, '1) * Provide Part Of Migrate * Done': {'posi': (1.25, 11)}, '1) * Modify Address * Negotiation': {'posi': (1.25, 49)}, '3) * Move Outdoor Same Exchange * Done': {'posi': (3.75, 17)}, '2) * Provide * Done': {'posi': (2.5, 12)}, '1) * Soft Suspend * Done': {'posi': (1.25, 3)}, '2) * Indoor transfer * Done': {'posi': (2.5, 28)}, '1) * Provide Part Of Move * Cancelled': {'posi': (1.25, 2 ...

# %%
# Draw the resulting graph
pos = nx.get_node_attributes(J,'posi')
nx.draw(J, pos ,with_labels=True, font_weight='bold', font_size = 7)
plt.show()

# %%
# clear edges
J.remove_edges_from(list(J.edges()))

# %%
#create edges with data (count, days, ave_days)

date_col = orders_df.columns.get_loc('ORDER_CREATION_DATE')
kpi = 5

for c in customers:

    temp_df = orders_df[orders_df[unique_col] == c]
  
    for i in range(len(temp_df)-1):
        #print(i, c)
        if J.has_edge(temp_df.iloc[i, -1], temp_df.iloc[(i+1),-1]) == False:
            #print(temp_df.iloc[i, -1], temp_df.iloc[(i+1),-1])
            #print(temp_df.iloc[i,-4], temp_df.iloc[(i+1),-4])
            J.add_edge(temp_df.iloc[i, -1], temp_df.iloc[(i+1),-1])
            J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count'] = 1
            difference = (temp_df.iloc[(i+1),date_col]-temp_df.iloc[i, date_col])
            J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['days'] = round(difference.total_seconds()/(60*60*24),1)
            J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['ave_days'] = round(J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['days']/ J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count'],1)
            
            if J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['ave_days'] > kpi:
                J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['color'] = 'red'
            else:
                J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['color'] = 'green'

        else:
            current_count = J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count']
            J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count'] = current_count + 1

            current_days =  J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['days']
            difference = (temp_df.iloc[(i+1),date_col]-temp_df.iloc[i, date_col])
            J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['days'] = round(current_days + difference.total_seconds()/(60*60*24),1)

            J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['ave_days'] = round(J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['days']/ J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count'],1)
            
            if J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['ave_days'] > kpi:
                J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['color'] = 'red'
            else:
                J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['color'] = 'green'

# %%
# add edge weight attribute

all_counts = []

#Iterate through the graph edges to gather all the weights
for (node1,node2,data) in J.edges(data=True):
    all_counts.append(data['count']) 

    
total_count = sum(all_counts)
max_count = max(all_counts)
min_count = min(all_counts)
ave_count = total_count/len(all_counts)
scale = 14

print(total_count)
print(max_count)
print(min_count)
print(ave_count)


if (max_count-min_count) == 0:
    for (node1,node2,data) in J.edges(data=True):
        J.edges[node1,node2]['weight'] = round(J.edges[node1,node2]['count'],1)

else:                                                
    for (node1,node2,data) in J.edges(data=True):
        J.edges[node1,node2]['weight'] = round(((J.edges[node1,node2]['count']-min_count)/(max_count-min_count))*scale+1,1)
# Out:
# 166
# 102
# 1
# 5.928571428571429

# %%
J.edges(data=True)
# Out:
# EdgeDataView([('1) * Indoor transfer * Cancelled', '2) * Indoor transfer * Done', {'color': 'red', 'weight': 1.0, 'count': 1, 'days': 6.9, 'ave_days': 6.9}), ('1) * Change - No Dispatch * Cancelled', '2) * Change - No Dispatch * Done', {'color': 'red', 'weight': 1.0, 'count': 1, 'days': 101.0, 'ave_days': 101.0}), ('1) * Move Outdoor Other Exchange * Negotiation', '2) * Cease Part Of Move * Negotiation', {'color': 'green', 'weight': 1.0, 'count': 1, 'days': 0.0, 'ave_days': 0.0}), ('1) * Move Outdoor Other Exchange * Done', '2) * Cease Part Of Move * Done', {'color': 'green', 'weight': 1.3, 'count': 3, 'days': 4.1, 'ave_days': 1.4}), ('1) * Provide Part Of Migrate * Amended', '2) * Provide Part Of Migrate * Done', {'color': 'red', 'weight': 1.0, 'count': 1, 'days': 11.0, 'ave_days': 11.0}), ('2) * Cease * Done', '1) * Cease * Cancelled', {'color': 'green', 'weight': 1.1, 'count': 2, 'days': 0.1, 'ave_days': 0.1}), ('1) * Change * Cancelled', '2) * Change * Done', {'color': 'red', 'weight': 1.3, 'count': 3, 'days': 18.0, 'ave_days': 6.0}), ('1) * Re-establish * Cancelled', '2) * Re-establish * Done', {'color': 'green', 'weight': 1.0, 'count': 1, 'days': 1.7, 'ave_days': 1.7}), ('1) * Provide Part Of Migrate * Cancelled', '2) * Provide Part Of Migrate * Done', {'color': 'green', 'weight': 1.8, 'count': 7, 'days': 12.1, 'ave_days': 1.7}), ('2) * Provide * Cancelled', '3) * Provide * Cancelled', {'color': 'green', 'weight': 1.1, 'count': 2, 'days': 0.0, 'ave_days': 0.0}), ('2) * Provide * Cancelled', '3) * Provide * Done', {'color': 'green', 'weight': 1.0, 'count': 1, 'days': 0.0, 'ave_days': 0.0}), ('2) * Provide * Cancelled', '1) * Provide * Cancelled', {'color': 'green', 'weight': 1.6, 'count': 5, 'days': 0.0, 'ave_days': 0.0}), ('4) * Cease Part Of Move * Done', '3) * Move Outdoor Other Exchange * Done', {'color': 'green', 'weight': 1.0, 'count': 1, 'days': 0.0, 'ave_days': 0.0}), ('1) * Change - T&M Dispatch * Cancelled', '2) * Change - T&M Dispatch * Done', {'color': 'green', 'weight': 1.0, 'count': 1, 'days': 3.7, 'ave_days': 3.7}), ('2) * Cease Part Of Migrate * Done', '1) * Cease Part Of Migrate * Cancelled', {'color': 'red', 'weight': 15.0, 'count': 102, 'days': 771.5, 'ave_days': 7.6}), ('2) * Cease Part Of Move * Cancelled', '1) * Move Outdoor Other Exchange * Cancelled', {'color': 'green', 'weight': 1.1, 'count': 2, 'days': 0.0, 'ave_days': 0.0}), ('2) * Cease Part Of Move * Cancelled', '3) * Move Outdoor Other Exchange * Done', {'color': 'red', 'weight': 1.0, 'count': 1, 'days': 7.0, 'ave_days': 7.0}), ('1) * Move Outdoor Same Exchange * Cancelled', '2) * Move Outdoor Same Exchange * Cancelled', {'color': 'red', 'weight': 1.1, 'count': 2, 'days': 21.0, 'ave_days': 10.5}), ('1) * Move Outdoor Same Exchange * Cancelled', '2) * Move Outdoor Same Exchange * Done', {'color': 'red', 'weight': 1.3, 'count': 3, 'days': 89.9, 'ave_days': 30.0}), ('2) * Change - Dispatchable * Done', '1) * Change - Dispatchable * Cancelled', {'color': 'green', 'weight': 1.0, 'count': 1, 'days': 2.9, 'ave_days': 2.9}), ('2) * Receive  Ownership * Done', '1) * Receive  Ownership * Cancelled', {'color': 'red', 'weight': 1.1, 'count': 2, 'days': 32.0, 'ave_days': 16.0}), ('2) * Move Outdoor Same Exchange * Cancelled', '3) * Move Outdoor Same Exchange * Cancelled', {'color': 'green', 'weight': 1.0, 'count': 1, 'days': 4.9, 'ave_days': 4.9}), ('2) * Move Outdoor Same Exchange * Cancelled', '3) * Move Outdoor Same Exchange * Done', {'color': 'red', 'weight': 1.0, 'count': 1, 'days': 239.0, 'ave_days': 239.0}), ('2) * Provide Part Of Migrate * Done', '1) * Cease Part Of Migrate * Done', {'color': 'green', 'weight': 1.1, 'count': 2, 'days': 0.0, 'ave_days': 0.0}), ('4) * Move Outdoor Same Exchange * Done', '3) * Move Outdoor Same Exchange * Cancelled', {'color': 'red', 'weight': 1.0, 'count': 1, 'days': 41.8, 'ave_days': 41.8}), ('1) * Provide * Cancelled', '2) * Provide * Done', {'color': 'green', 'weight': 2.8, 'count': 14, 'days': 17.7, 'ave_days':  ...

# %%
# Draw the resulting graph

#mpl_fig = plt.figure()
mpl_fig, ax = plt.subplots(1,1)

#pos = nx.circular_layout(J)
pos = nx.get_node_attributes(J,'posi')
edges,colors = zip(*nx.get_edge_attributes(J,'color').items())
edges,width = zip(*nx.get_edge_attributes(J,'weight').items())


nx.draw(J,pos, ax=ax, with_labels=True, font_weight='bold', font_size = 8, edgelist=edges, edge_color=colors, width = width
       )

edge_labels  = nx.get_edge_attributes(J,'ave_days')
#label_color  = nx.get_edge_attributes(J,'color').values()

#print(pos)

for e in J.edges(data=True):
    #print(e)
    #print(e[0])
    #print(e[1])
    #print(e[2])
    #print(e[2]['color'])
    nx.draw_networkx_edge_labels(J,ax=ax, pos=pos,edge_labels={(e[0],e[1]):e[2]['ave_days']}, font_color = e[2]['color'])

plt.savefig('stage_transition_edge_colour')
plt.show()

# %%
type(mpl_fig)
# Out:
# matplotlib.figure.Figure

# %%
mpl_fig

# %%
#pip install dash==1.4.1

# %%
#pip install chart_studio

# %%
import chart_studio.plotly as py
from plotly.tools import mpl_to_plotly
import dash_core_components as dcc

# %%
import ipywidgets

# %%
plotly_fig = mpl_to_plotly(mpl_fig)

# %%
plotly_fig
# Out:
# <div>
#
#
#             <div id="feb67d87-9244-4b1f-8faa-73d048a64643" class="plotly-graph-div" style="height:1440px; width:1440px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("feb67d87-9244-4b1f-8faa-73d048a64643")) {
#                     Plotly.newPlot(
#                         'feb67d87-9244-4b1f-8faa-73d048a64643',
#                         [{"marker": {"color": "rgba(31,120,180,1.0)", "line": {"color": "rgba(31,120,180,1.0)", "width": 1.0}, "size": 17.320508075688775, "symbol": "circle"}, "mode": "markers", "type": "scatter", "x": [1.25, 1.25, 1.25, 1.25, 1.25, 1.25, 2.5, 1.25, 1.25, 1.25, 1.25, 1.25, 2.5, 1.25, 2.5, 2.5, 5.0, 1.25, 1.25, 2.5, 1.25, 1.25, 1.25, 2.5, 1.25, 2.5, 2.5, 1.25, 1.25, 1.25, 1.25, 2.5, 1.25, 1.25, 2.5, 1.25, 2.5, 2.5, 1.25, 3.75, 1.25, 2.5, 1.25, 3.75, 2.5, 5.0, 1.25, 1.25, 1.25, 1.25, 1.25, 2.5, 1.25, 1.25, 0.4, 1.25, 5.0, 1.25, 1.25, 1.25, 3.75, 2.5, 1.25, 1.25, 1.25, 1.25, 1.25, 3.75, 2.5, 1.25, 3.75, 1.25, 2.5], "xaxis": "x", "y": [33.0, 18.0, 42.0, 38.0, 21.0, 40.0, 10.0, 26.0, 12.0, 13.0, 15.0, 46.0, 43.0, 30.0, 25.0, 16.0, 22.0, 37.0, 6.0, 9.0, 10.0, 8.0, 49.0, 7.0, 4.0, 22.0, 20.0, 34.0, 24.0, 14.0, 28.0, 45.0, 7.0, 19.0, 17.0, 39.0, 26.0, 6.0, 29.0, 21.0, 22.0, 14.0, 36.0, 25.0, 11.0, 17.0, 35.0, 25.0, 48.0, 17.0, 47.0, 32.0, 44.0, 2.0, 10.0, 27.0, 12.0, 41.0, 5.0, 3.0, 12.0, 24.0, 31.0, 1.0, 16.0, 11.0, 32.0, 17.0, 12.0, 23.0, 14.0, 9.0, 28.0], "yaxis": "y"}],
#                         {"annotations": [{"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Move Outdoor Other Exchange * Cancelled", "x": 1.25, "xanchor": "center", "xref": "x", "y": 19.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Change - No Dispatch * Cancelled", "x": 1.25, "xanchor": "center", "xref": "x", "y": 18.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Move Outdoor Other Exchange * Negotiation", "x": 1.25, "xanchor": "center", "xref": "x", "y": 42.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Provide Same As * Cancelled", "x": 1.25, "xanchor": "center", "xref": "x", "y": 38.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Provide * Cancelled", "x": 1.25, "xanchor": "center", "xref": "x", "y": 25.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Provide Part Of Migrate * Amended", "x": 1.25, "xanchor": "center", "xref": "x", "y": 40.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "2) * Cease * Done", "x": 2.5, "xanchor": "center", "xref": "x", "y": 10.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Change - Dispatchable * Done", "x": 1.25, "xanchor": "center", "xref": "x", "y": 26.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Provide * Done", "x": 1.25, "xanchor": "center", "xref": "x", "y": 12.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Cease * Cancelled", "x": 1.25, "xanchor": "center", "xref": "x", "y": 13.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Change * Cancelled", "x": 1.25, "xanchor": "center", "xref": "x", "y": 15.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Re-establish * Cancelled", "x": 1.25, "xanchor": "center", "xref": "x", "y": 46.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "2) * Cease Part Of Move * Negotiation", "x": 2.5, "xanchor": "center", "xref": "x", "y": 43.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Provide Part Of Migrate * Cancelled", "x": 1.25, "xanchor": "center", "xref": "x", "y": 30.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "2) * Change * Done", "x": 2.5, "xanchor": "center", "xref": "x", "y": 16.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Move Outdoor Same Exchange * Done", "x": 1.25, "xanchor": "center", "xref": "x", "y": 17.0, "yanchor": "middle", "yref": "y"}, {"align": "center", "font": {"color": "#000000", "size": 8.0}, "opacity": 1.0, "showarrow": false, "text": "1) * Cease Part Of Migrate * Completion", "x": 1.25, "xanchor": "center", "xref": "x", "y": 36.0, "yanchor": "middle", "yref" ...

# %%
graph = dcc.Graph(id='myGraph', figure=plotly_fig)  # figure not fig

# %%
graph
# Out:
# Graph(id='myGraph', figure=Figure({
#     'data': [{'marker': {'color': 'rgba(31,120,180,1.0)',
#                          'line': {'color': 'rgba(31,120,180,1.0)', 'width': 1.0},
#                          'size': 17.320508075688775,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'type': 'scatter',
#               'x': [1.25, 1.25, 1.25, 1.25, 1.25, 1.25, 2.5, 1.25, 1.25, 1.25,
#                     1.25, 1.25, 2.5, 1.25, 2.5, 2.5, 5.0, 1.25, 1.25, 2.5, 1.25,
#                     1.25, 1.25, 2.5, 1.25, 2.5, 2.5, 1.25, 1.25, 1.25, 1.25, 2.5,
#                     1.25, 1.25, 2.5, 1.25, 2.5, 2.5, 1.25, 3.75, 1.25, 2.5, 1.25,
#                     3.75, 2.5, 5.0, 1.25, 1.25, 1.25, 1.25, 1.25, 2.5, 1.25, 1.25,
#                     0.4, 1.25, 5.0, 1.25, 1.25, 1.25, 3.75, 2.5, 1.25, 1.25, 1.25,
#                     1.25, 1.25, 3.75, 2.5, 1.25, 3.75, 1.25, 2.5],
#               'xaxis': 'x',
#               'y': [33.0, 18.0, 42.0, 38.0, 21.0, 40.0, 10.0, 26.0, 12.0, 13.0,
#                     15.0, 46.0, 43.0, 30.0, 25.0, 16.0, 22.0, 37.0, 6.0, 9.0, 10.0,
#                     8.0, 49.0, 7.0, 4.0, 22.0, 20.0, 34.0, 24.0, 14.0, 28.0, 45.0,
#                     7.0, 19.0, 17.0, 39.0, 26.0, 6.0, 29.0, 21.0, 22.0, 14.0, 36.0,
#                     25.0, 11.0, 17.0, 35.0, 25.0, 48.0, 17.0, 47.0, 32.0, 44.0,
#                     2.0, 10.0, 27.0, 12.0, 41.0, 5.0, 3.0, 12.0, 24.0, 31.0, 1.0,
#                     16.0, 11.0, 32.0, 17.0, 12.0, 23.0, 14.0, 9.0, 28.0],
#               'yaxis': 'y'}],
#     'layout': {'annotations': [{'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Move Outdoor Other Exchange * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 19.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change - No Dispatch * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 18.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Move Outdoor Other Exchange * Negotiation',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 42.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Provide Same As * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 38.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Provide * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 25.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Provide Part Of Migrate * Amended',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 40.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Cease * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 10.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change - Dispatchable * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 26.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Provide * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 12.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 13.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 15.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Re-establish * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 46.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Cease Part Of Move * Negotiation',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 43.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Provide Part Of Migrate * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 30.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Change * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 16.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Move Outdoor Same Exchange * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 17.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease Part Of Migrate * Completion',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 36.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Receive  Ownership * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 6.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Cease Part Of Migrate * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 9.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease Part Of Migrate * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 8.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Re-establish * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 32.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Change - No Dispatch * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 7.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Hard Suspend * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 4.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Cease Part Of Move * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 22.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Cease Part Of Move * Cancelled',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 20.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change BAN To BAN * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 39.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Provide Part Of Move * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 24.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 16.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Move Outdoor Same Exchange * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 14.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Indoor transfer * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 28.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Change - T&M Dispatch * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 45.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Provide * Cancelled',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 25.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Indoor transfer * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 33.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Move Outdoor Same Exchange * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 17.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease due to Collection * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 27.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Change - Dispatchable * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 26.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Receive  Ownership * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 6.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease Part Of Move * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 22.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '3) * Move Outdoor Other Exchange * Done',
#                                 'x': 3.75,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 21.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Modify Address * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 29.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Move Outdoor Same Exchange * Cancelled',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 14.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change BAN To BAN * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 34.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '3) * Provide * Cancelled',
#                                 'x': 3.75,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 25.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Provide Part Of Migrate * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 11.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '4) * Move Outdoor Same Exchange * Done',
#                                 'x': 5.0,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 17.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change SN * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 35.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Move Outdoor Other Exchange * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 21.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease Part Of Migrate * Negotiation',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 48.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change - T&M Dispatch * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 37.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease * Negotiation',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 47.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Re-establish * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 32.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Move Outdoor Same Exchange * Delivery',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 44.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease due to Collection * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 2.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': 'TBi',
#                                 'x': 0.4,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 10.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 10.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '4) * Provide * Done',
#                                 'x': 5.0,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 12.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease * Delivery',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 41.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change - Dispatchable * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 5.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '4) * Cease Part Of Move * Done',
#                                 'x': 5.0,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 22.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Provide Part Of Move * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 24.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Receive  Ownership * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 31.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Resume from Suspension due to Collection * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 1.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Change - No Dispatch * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 7.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Provide Part Of Migrate * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 11.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Modify Address * Negotiation',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 49.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '3) * Move Outdoor Same Exchange * Done',
#                                 'x': 3.75,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 17.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Provide * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 12.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Soft Suspend * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 3.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2) * Indoor transfer * Done',
#                                 'x': 2.5,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 28.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Provide Part Of Move * Cancelled',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 23.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '3) * Move Outdoor Same Exchange * Cancelled',
#                                 'x': 3.75,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 14.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1) * Cease Part Of Migrate * Done',
#                                 'x': 1.25,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 9.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'size': 8.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '3) * Provide * Done',
#                                 'x': 3.75,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 12.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '6.9',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 30.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '101.0',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 12.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '0.0',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 42.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1.4',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 21.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '11.0',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 25.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '0.1',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 11.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '6.0',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 15.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1.7',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 39.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1.7',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 20.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '0.0',
#                                 'x': 3.125,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 25.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '0.0',
#                                 'x': 3.125,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 18.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '0.0',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 25.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '0.0',
#                                 'x': 4.375,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 21.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '3.7',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 41.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '7.6',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 8.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '0.0',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 19.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '7.0',
#                                 'x': 3.125,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 20.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '10.5',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 14.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '30.0',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 15.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '2.9',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 15.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '16.0',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 18.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '4.9',
#                                 'x': 3.125,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 14.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '239.0',
#                                 'x': 3.125,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 15.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '0.0',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 10.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '41.8',
#                                 'x': 4.375,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 15.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '1.3',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 18.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#008000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '0.0',
#                                 'x': 4.375,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 12.0,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#FF0000', 'size': 10.0},
#                                 'opacity': 1.0,
#                                 'showarrow': False,
#                                 'text': '42.7',
#                                 'x': 1.875,
#                                 'xanchor': 'center',
#                                 'xref': 'x',
#                                 'y': 23.5,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'}],
#                'autosize': False,
#                'height': 1440,
#                'hovermode': 'closest',
#                'margin': {'b': 180, 'l': 180, 'pad': 0, 'r': 143, 't': 172},
#                'showlegend': False,
#                'template': '...',
#                'width': 1440,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'mirror': 'ticks',
#                          'nticks': 7,
#                          'range': [0.16146390731036855, 5.238536092689632],
#                          'showgrid': False,
#                          'showline': True,
#                          'side': 'top',
#                          'ticks': 'inside',
#                          'type': 'linear',
#                          'zeroline': False},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.0, 1.0],
#                          'mirror': 'ticks',
#                          'nticks': 8,
#                          'range': [-1.4087622143502843, 51.40876221435028],
#                          'showgrid': False,
#                          'showline': True,
#                          'side': 'right',
#                          'ticks': 'inside',
#                          'type': 'linear',
#                          'zeroline': False}}
# }))

# %%
# Draw the resulting graph
#pos = nx.circular_layout(J)
pos = nx.get_node_attributes(J,'posi')
nx.draw(J,pos, with_labels=True, font_size = 7
        #, arrowstyle='->',arrowsize=15
       )

edge_labels = nx.get_edge_attributes(J, 'count')
nx.draw_networkx_edge_labels(J,pos,edge_labels=edge_labels,font_color='red')

plt.show()

# %%
orders_df[orders_df['stage_ActionType_OrderStatus']=='2) * Cease Part Of Move * Cancelled']['MSISDN_ANON'].unique()
# Out:
# array(['3842282672409691663', '3665642364268550244'], dtype=object)

# %%
#orders_df[orders_df['MSISDN_ANON']=='91450653458314736']
