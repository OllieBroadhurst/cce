# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
#pip install pygraphviz
#import pygraphviz
# Out:
#   File "<ipython-input-50-5cda7b71b964>", line 5
#     pip install pygraphviz
#               ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 10]

# %%
# %%bigquery --project bcx-insights customers_3 --verbose
#
# SELECT *
#
# FROM `bcx-insights.telkom_customerexperience.orders_20190926_00_anon`
#
# WHERE DEAL_DESC = 'SmartBroadband Wireless 20GB Deal'
#
# ORDER BY ORDER_CREATION_DATE, ACTION_CREATION_DATE, ORDER_ID_ANON
# Out:
# Executing query with job ID: c3f208b9-c13a-441e-abb0-f41402378ad5
# Query executing: 0.29s
# Query complete after 0.48s

# %%
customers_3.tail(3)
# Out:
#       ORDER_STATUS_DESC       ORDER_CREATION_DATE ACTION_STATUS_DESC  \
# 73963              Done 2019-09-18 21:13:41+00:00               Done
# 73964              Done 2019-09-18 21:16:56+00:00               Done
# 73965              Done 2019-09-18 21:17:45+00:00               Done
#
#       ACTION_TYPE ACTION_TYPE_DESC      ACTION_CREATION_DATE  \
# 73963          PR          Provide 2019-09-18 21:13:41+00:00
# 73964          PR          Provide 2019-09-18 21:16:56+00:00
# 73965          PR          Provide 2019-09-18 21:17:45+00:00
#
#       ORIGINAL_SALES_CHANNEL_DESC CURRENT_SALES_CHANNEL_DESC  \
# 73963                 Call Center                Call Center
# 73964                 Call Center                Call Center
# 73965                 Call Center                Call Center
#
#                                DEAL_DESC                 PROV_DATE  \
# 73963  SmartBroadband Wireless 20GB Deal 2019-09-18 21:14:07+00:00
# 73964  SmartBroadband Wireless 20GB Deal 2019-09-18 21:17:22+00:00
# 73965  SmartBroadband Wireless 20GB Deal 2019-09-18 21:18:07+00:00
#
#                      CLOSE_DATE OPEN_CLOSE_INDIC SOURCE        ORDER_ID_ANON  \
# 73963 2019-09-18 21:14:07+00:00                C    NGN -5452963134605644357
# 73964 2019-09-18 21:17:22+00:00                C    NGN -3861971997209067679
# 73965 2019-09-18 21:18:07+00:00                C    NGN  4213499607793677342
#
#            ACCOUNT_NO_ANON          MSISDN_ANON  ORDER_ACTION_ID_ANON
# 73963  3553008416154642013 -8780630124271807595  -3154332177942909412
# 73964  3553008416154642013  -468472096676769145   1785951227348079728
# 73965  3553008416154642013 -5579602106860421269    393783649302723256

# %%
len(customers_3)
# Out:
# 73966

# %%
customers_3 = customers_3.drop_duplicates()

# %%
len(customers_3)
# Out:
# 63952

# %%
customers_3['MSISDN_ANON'] = customers_3['MSISDN_ANON'].astype(str)

# %%
unique_col = 'ORDER_ID_ANON'

# %%
customers_3['stage'] = customers_3.groupby(unique_col).cumcount()+1

# %%
customers_3['stage'] = customers_3['stage'].astype(str)

# %%
customers_3['ActionType_OrderStatus'] = customers_3['ACTION_TYPE_DESC'] +' * '+ customers_3['ORDER_STATUS_DESC']

# %%
type_status = list(customers_3['ActionType_OrderStatus'].unique())

# %%
customers_3['stage_ActionType_OrderStatus'] = customers_3['stage'] +') * '+ customers_3['ACTION_TYPE_DESC'] +' * '+ customers_3['ORDER_STATUS_DESC']

# %%
customers_3.tail(3)
# Out:
#       ORDER_STATUS_DESC       ORDER_CREATION_DATE ACTION_STATUS_DESC  \
# 73963              Done 2019-09-18 21:13:41+00:00               Done
# 73964              Done 2019-09-18 21:16:56+00:00               Done
# 73965              Done 2019-09-18 21:17:45+00:00               Done
#
#       ACTION_TYPE ACTION_TYPE_DESC      ACTION_CREATION_DATE  \
# 73963          PR          Provide 2019-09-18 21:13:41+00:00
# 73964          PR          Provide 2019-09-18 21:16:56+00:00
# 73965          PR          Provide 2019-09-18 21:17:45+00:00
#
#       ORIGINAL_SALES_CHANNEL_DESC CURRENT_SALES_CHANNEL_DESC  \
# 73963                 Call Center                Call Center
# 73964                 Call Center                Call Center
# 73965                 Call Center                Call Center
#
#                                DEAL_DESC                 PROV_DATE  \
# 73963  SmartBroadband Wireless 20GB Deal 2019-09-18 21:14:07+00:00
# 73964  SmartBroadband Wireless 20GB Deal 2019-09-18 21:17:22+00:00
# 73965  SmartBroadband Wireless 20GB Deal 2019-09-18 21:18:07+00:00
#
#                      CLOSE_DATE OPEN_CLOSE_INDIC SOURCE        ORDER_ID_ANON  \
# 73963 2019-09-18 21:14:07+00:00                C    NGN -5452963134605644357
# 73964 2019-09-18 21:17:22+00:00                C    NGN -3861971997209067679
# 73965 2019-09-18 21:18:07+00:00                C    NGN  4213499607793677342
#
#            ACCOUNT_NO_ANON           MSISDN_ANON  ORDER_ACTION_ID_ANON stage  \
# 73963  3553008416154642013  -8780630124271807595  -3154332177942909412     1
# 73964  3553008416154642013   -468472096676769145   1785951227348079728     1
# 73965  3553008416154642013  -5579602106860421269    393783649302723256     1
#
#       ActionType_OrderStatus stage_ActionType_OrderStatus
# 73963         Provide * Done          1) * Provide * Done
# 73964         Provide * Done          1) * Provide * Done
# 73965         Provide * Done          1) * Provide * Done

# %%
customers = list(customers_3[unique_col].unique())

# %%
sorted_df = customers_3.sort_values('stage', ascending=False).head(3)
sorted_df.head()
# Out:
#       ORDER_STATUS_DESC       ORDER_CREATION_DATE ACTION_STATUS_DESC  \
# 25079              Done 2019-07-06 11:04:43+00:00               Done
# 25078              Done 2019-07-06 11:04:43+00:00               Done
# 48481              Done 2019-08-14 14:15:45+00:00               Done
#
#       ACTION_TYPE ACTION_TYPE_DESC      ACTION_CREATION_DATE  \
# 25079          PR          Provide 2019-07-06 11:04:43+00:00
# 25078          PR          Provide 2019-07-06 11:04:43+00:00
# 48481          PR          Provide 2019-08-14 14:15:45+00:00
#
#       ORIGINAL_SALES_CHANNEL_DESC CURRENT_SALES_CHANNEL_DESC  \
# 25079                 Call Center                Call Center
# 25078                 Call Center                Call Center
# 48481                 Call Center                Call Center
#
#                                DEAL_DESC                 PROV_DATE  \
# 25079  SmartBroadband Wireless 20GB Deal 2019-07-06 11:40:33+00:00
# 25078  SmartBroadband Wireless 20GB Deal 2019-07-06 11:40:33+00:00
# 48481  SmartBroadband Wireless 20GB Deal 2019-08-16 14:40:38+00:00
#
#                      CLOSE_DATE OPEN_CLOSE_INDIC SOURCE        ORDER_ID_ANON  \
# 25079 2019-07-06 11:40:33+00:00                C    NGN   534054793263945555
# 25078 2019-07-06 11:40:33+00:00                C    NGN   534054793263945555
# 48481 2019-08-16 14:40:38+00:00                C    NGN  5834177311676859304
#
#            ACCOUNT_NO_ANON           MSISDN_ANON  ORDER_ACTION_ID_ANON stage  \
# 25079  1612443932842656633   4103364350320324992  -7082338567608815847     7
# 25078  1612443932842656633   7318006168441282118  -2975044637407197719     6
# 48481 -4490557944858168522  -8818064735780512688    494801825042585798     6
#
#       ActionType_OrderStatus stage_ActionType_OrderStatus
# 25079         Provide * Done          7) * Provide * Done
# 25078         Provide * Done          6) * Provide * Done
# 48481         Provide * Done          6) * Provide * Done

# %%
len(customers_3[customers_3['stage']=='2'])
# Out:
# 90

# %%
len(customers)
# Out:
# 63811

# %%
# Create a networkx graph object
J = nx.Graph()

# %%
J.clear()

# %%
max_stage=max(customers_3['stage'].astype(int))
max_stage
# Out:
# 7

# %%
actions = list(customers_3['stage_ActionType_OrderStatus'].unique())

# %%
J.add_node('DEAL',posi=(10,0), color = 'purple')

# %%
for i in range(1,max_stage+1):
  
  stage_actions = list(customers_3[customers_3['stage']==str(i)]['stage_ActionType_OrderStatus'].unique())
  #print(stage_actions)
  for k in range(len(stage_actions)):
    label = stage_actions[k]
    #print(label)
    label = label.split('* ',1)
    label = label[1]
    #print(label)
    height =  type_status.index(label) +1
    #print(height)
    J.add_node(stage_actions[k],posi=(i*1.25,height))
    #print(stage_actions[k])
    #print((i,k+1))

# %%
J.nodes(data = True)
# Out:
# NodeDataView({'1) * Collection Cease * Done': {'posi': (1.25, 12)}, 'DEAL': {'posi': (10, 0), 'color': 'purple'}, '1) * Cease * Done': {'posi': (1.25, 3)}, '2) * Change Ownership * Done': {'posi': (2.5, 8)}, '1) * Provide * Delivery': {'posi': (1.25, 4)}, '1) * Change Ownership * Delivery': {'posi': (1.25, 22)}, '1) * Change * Delivery': {'posi': (1.25, 5)}, '3) * Cease * Done': {'posi': (3.75, 3)}, '3) * Provide * Negotiation': {'posi': (3.75, 11)}, '3) * Provide * Done': {'posi': (3.75, 2)}, '1) * Provide * Negotiation': {'posi': (1.25, 11)}, '2) * Provide * Done': {'posi': (2.5, 2)}, '1) * Change Part of Replace Offer * Initial': {'posi': (1.25, 13)}, '1) * Change Part of Replace Offer * Done': {'posi': (1.25, 6)}, '1) * Change Part of Replace Offer * Negotiation': {'posi': (1.25, 14)}, '2) * Change Part of Replace Offer * Done': {'posi': (2.5, 6)}, '5) * Provide * Done': {'posi': (6.25, 2)}, '7) * Provide * Done': {'posi': (8.75, 2)}, '1) * Change * Negotiation': {'posi': (1.25, 16)}, '1) * Change * Completion': {'posi': (1.25, 21)}, '3) * Change * Done': {'posi': (3.75, 1)}, '1) * Change Ownership * Negotiation': {'posi': (1.25, 15)}, '6) * Provide * Done': {'posi': (7.5, 2)}, '1) * Collection Resume * Done': {'posi': (1.25, 9)}, '1) * Change * Done': {'posi': (1.25, 1)}, '2) * Provide * Negotiation': {'posi': (2.5, 11)}, '2) * Change * Done': {'posi': (2.5, 1)}, '1) * Collection Suspend * Done': {'posi': (1.25, 7)}, '1) * Cease * Negotiation': {'posi': (1.25, 19)}, '1) * Change Part of Replace Offer * Delivery': {'posi': (1.25, 18)}, '1) * Resume * Done': {'posi': (1.25, 10)}, '4) * Provide * Done': {'posi': (5.0, 2)}, '2) * Cease * Done': {'posi': (2.5, 3)}, '2) * Provide * Delivery': {'posi': (2.5, 4)}, '1) * Change Part of Replace Offer * Completion': {'posi': (1.25, 20)}, '1) * Provide * Done': {'posi': (1.25, 2)}, '1) * Provide * To Be Cancelled': {'posi': (1.25, 17)}, '1) * Change Ownership * Done': {'posi': (1.25, 8)}})

# %%
# Draw the resulting graph
pos = nx.get_node_attributes(J,'posi')
nx.draw(J, pos ,with_labels=True, font_weight='bold', font_size = 7)
plt.show()

# %%
# clear edges
J.remove_edges_from(list(J.edges()))

# %%
#create edges with data (count, minutes, ave_minutes)

date_col = customers_3.columns.get_loc('ACTION_CREATION_DATE')

for c in customers:

    temp_df = customers_3[customers_3[unique_col] == c]
  
    for i in range(len(temp_df)-1):
        #print(i, c)
        if J.has_edge(temp_df.iloc[i, -1], temp_df.iloc[(i+1),-1]) == False:
          #print(temp_df.iloc[i, -1], temp_df.iloc[(i+1),-1])
          #print(temp_df.iloc[i,-4], temp_df.iloc[(i+1),-4])
          J.add_edge(temp_df.iloc[i, -1], temp_df.iloc[(i+1),-1])
          J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count'] = 1
          difference = (temp_df.iloc[(i+1),date_col]-temp_df.iloc[i, date_col])
          J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['minutes'] = round(difference.total_seconds()/(60),1)
          J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['ave_minutes'] = round(J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['minutes']/ J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count'],1)

        else:
          current_count = J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count']
          J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count'] = current_count + 1

          current_minutes =  J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['minutes']
          difference = (temp_df.iloc[(i+1),date_col]-temp_df.iloc[i, date_col])
          J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['minutes'] = round(current_minutes + difference.total_seconds()/(60),1)

          current_ave_minutes =  J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['ave_minutes'] = round(J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['minutes']/ J.edges[temp_df.iloc[i, -1],temp_df.iloc[(i+1),-1]]['count'],1)

# %%
J.edges()
# Out:
# EdgeView([('1) * Cease * Done', '2) * Cease * Done'), ('2) * Change Ownership * Done', '1) * Change Ownership * Done'), ('2) * Cease * Done', '3) * Cease * Done'), ('2) * Provide * Delivery', '1) * Provide * To Be Cancelled'), ('3) * Provide * Negotiation', '2) * Provide * Negotiation'), ('3) * Provide * Done', '2) * Provide * Done'), ('3) * Provide * Done', '4) * Provide * Done'), ('1) * Provide * Negotiation', '2) * Provide * Negotiation'), ('2) * Provide * Done', '1) * Provide * Done'), ('1) * Change Part of Replace Offer * Done', '2) * Change Part of Replace Offer * Done'), ('5) * Provide * Done', '6) * Provide * Done'), ('5) * Provide * Done', '4) * Provide * Done'), ('7) * Provide * Done', '6) * Provide * Done'), ('2) * Provide * Negotiation', '1) * Provide * To Be Cancelled'), ('3) * Change * Done', '2) * Change * Done'), ('1) * Change * Done', '2) * Change * Done')])

# %%
# Draw the resulting graph
#pos = nx.circular_layout(J)
pos = nx.get_node_attributes(J,'posi')
nx.draw(J,pos, with_labels=True, font_weight='bold', font_size = 7
        #, arrowstyle='->',arrowsize=15
       )

edge_labels = nx.get_edge_attributes(J, 'count')
nx.draw_networkx_edge_labels(J,pos,edge_labels=edge_labels,font_color='red')


plt.show()

# %%
# Draw the resulting graph
#pos = nx.circular_layout(J)
pos = nx.get_node_attributes(J,'posi')
nx.draw(J,pos, with_labels=True, font_size = 7
        #, arrowstyle='->',arrowsize=15
       )

edge_labels = nx.get_edge_attributes(J, 'minutes')
nx.draw_networkx_edge_labels(J,pos,edge_labels=edge_labels,font_color='red')

plt.show()

# %%
# Draw the resulting graph
#pos = nx.circular_layout(J)

pos = nx.get_node_attributes(J,'posi')

nx.draw(J,pos, with_labels=True, font_size=7
        #, arrowstyle='->',arrowsize=15
       )

edge_labels = nx.get_edge_attributes(J, 'ave_minutes')
nx.draw_networkx_edge_labels(J,pos,edge_labels=edge_labels,font_color='red')

plt.show()

# %%
# Draw the resulting graph
#pos = nx.circular_layout(J)
pos = nx.get_node_attributes(J,'posi')
nx.draw(J,pos, with_labels=True, font_weight='bold', font_size = 7)

edge_labels = nx.get_edge_attributes(J, 'ave_minutes')

all_counts = []
#4 a. Iterate through the graph nodes to gather all the weights
for (node1,node2,data) in J.edges(data=True):
    all_counts.append(data['count']) #we'll use this when determining edge thickness

#4 b. Get unique weights
unique_counts = list(set(all_counts))
 
#4 c. Plot the edges - one by one!
for count in unique_counts:
        #4 d. Form a filtered list with just the weight you want to draw
        counted_edges = [(node1,node2) for (node1,node2,edge_attr) in J.edges(data=True) if edge_attr['count']==count]
        #4 e. I think multiplying by [num_nodes/sum(all_weights)] makes the graphs edges look cleaner
        width = count*len(actions)*2/sum(all_counts)
        nx.draw_networkx_edges(J,pos,edgelist=counted_edges,width=width, edge_color = 'grey')

nx.draw_networkx_edge_labels(J,pos,edge_labels=edge_labels,font_color='green')
plt.savefig('stage_transition')
plt.show()

# %%
J_df = nx.to_pandas_edgelist(J)

# %%
J_df
# Out:
#     ave_minutes  count  minutes                                    source  \
# 0           0.0      5      0.0                         1) * Cease * Done
# 1           0.0      2      0.0              2) * Change Ownership * Done
# 2           0.0      1      0.0                         2) * Cease * Done
# 3           4.3      2      8.7                   2) * Provide * Delivery
# 4           0.0      1      0.0                3) * Provide * Negotiation
# 5           0.0     23      0.0                       3) * Provide * Done
# 6           0.0     14      0.0                       3) * Provide * Done
# 7           0.0      5      0.0                1) * Provide * Negotiation
# 8           0.0     68      0.0                       2) * Provide * Done
# 9           0.0      1      0.0  1) * Change Part of Replace Offer * Done
# 10          0.0      4      0.0                       5) * Provide * Done
# 11          0.0      6      0.0                       5) * Provide * Done
# 12          0.0      1      0.0                       7) * Provide * Done
# 13         16.3      6     98.0                2) * Provide * Negotiation
# 14          0.0      1      0.0                        3) * Change * Done
# 15          0.0      1      0.0                        1) * Change * Done
#
#                                       target
# 0                          2) * Cease * Done
# 1               1) * Change Ownership * Done
# 2                          3) * Cease * Done
# 3             1) * Provide * To Be Cancelled
# 4                 2) * Provide * Negotiation
# 5                        2) * Provide * Done
# 6                        4) * Provide * Done
# 7                 2) * Provide * Negotiation
# 8                        1) * Provide * Done
# 9   2) * Change Part of Replace Offer * Done
# 10                       6) * Provide * Done
# 11                       4) * Provide * Done
# 12                       6) * Provide * Done
# 13            1) * Provide * To Be Cancelled
# 14                        2) * Change * Done
# 15                        2) * Change * Done

# %%
CJ = J

# %%
CJ.remove_nodes_from(list(nx.isolates(J)))

# %%
CJ.nodes(data=True)
# Out:
# NodeDataView({'3) * Provide * Done': {'posi': (3.75, 2)}, '5) * Provide * Done': {'posi': (6.25, 2)}, '1) * Cease * Done': {'posi': (1.25, 3)}, '2) * Change Ownership * Done': {'posi': (2.5, 8)}, '2) * Provide * Negotiation': {'posi': (2.5, 11)}, '3) * Cease * Done': {'posi': (3.75, 3)}, '3) * Provide * Negotiation': {'posi': (3.75, 11)}, '2) * Change Part of Replace Offer * Done': {'posi': (2.5, 6)}, '2) * Provide * Done': {'posi': (2.5, 2)}, '1) * Provide * Negotiation': {'posi': (1.25, 11)}, '1) * Change Part of Replace Offer * Done': {'posi': (1.25, 6)}, '4) * Provide * Done': {'posi': (5.0, 2)}, '7) * Provide * Done': {'posi': (8.75, 2)}, '3) * Change * Done': {'posi': (3.75, 1)}, '6) * Provide * Done': {'posi': (7.5, 2)}, '1) * Change * Done': {'posi': (1.25, 1)}, '2) * Change * Done': {'posi': (2.5, 1)}, '2) * Cease * Done': {'posi': (2.5, 3)}, '2) * Provide * Delivery': {'posi': (2.5, 4)}, '1) * Provide * Done': {'posi': (1.25, 2)}, '1) * Provide * To Be Cancelled': {'posi': (1.25, 17)}, '1) * Change Ownership * Done': {'posi': (1.25, 8)}})

# %%
#CJ.add_node('dummy',posi=(0,10))

# Draw the resulting graph

plt.rcParams['figure.figsize'] = [20, 8]

pos = nx.get_node_attributes(CJ,'posi')
nx.draw(CJ,pos, with_labels=True, font_weight='bold', font_size = 7)

edge_labels = nx.get_edge_attributes(CJ, 'ave_minutes')

all_counts = []
#4 a. Iterate through the graph nodes to gather all the weights
for (node1,node2,data) in CJ.edges(data=True):
    all_counts.append(data['count']) #we'll use this when determining edge thickness

#4 b. Get unique weights
unique_counts = list(set(all_counts))
 
#4 c. Plot the edges - one by one!
for count in unique_counts:
        #4 d. Form a filtered list with CJust the weight you want to draw
        counted_edges = [(node1,node2) for (node1,node2,edge_attr) in CJ.edges(data=True) if edge_attr['count']==count]
        #4 e. I think multiplying by [num_nodes/sum(all_weights)] makes the graphs edges look cleaner
        width = count*len(actions)*2/sum(all_counts)
        nx.draw_networkx_edges(CJ,pos,edgelist=counted_edges,width=width, edge_color = 'grey')

nx.draw_networkx_edge_labels(CJ,pos,edge_labels=edge_labels,font_color='green')
plt.savefig('stage_transition_onlymulti')
plt.show()

# %%
a = nx.nx_agraph.graphviz_layout(J)
b = nx.readwrite.json_graph.cytoscape_data(J)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_agraph.py in pygraphviz_layout(G, prog, root, args)
#     282     try:
# --> 283         import pygraphviz
#     284     except ImportError:
#
# ImportError: No module named 'pygraphviz'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-d3abf32b673d> in <module>
# ----> 1 a = nx.nx_agraph.graphviz_layout(J)
#       2 b = nx.readwrite.json_graph.cytoscape_data(J)
#
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_agraph.py in graphviz_layout(G, prog, root, args)
#     241     This is a wrapper for pygraphviz_layout.
#     242     """
# --> 243     return pygraphviz_layout(G, prog=prog, root=root, args=args)
#     244
#     245
#
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_agraph.py in pygraphviz_layout(G, prog, root, args)
#     284     except ImportError:
#     285         raise ImportError('requires pygraphviz ',
# --> 286                           'http://pygraphviz.github.io/')
#     287     if root is not None:
#     288         args += "-Groot=%s" % root
#
# ImportError: ('requires pygraphviz ', 'http://pygraphviz.github.io/')
